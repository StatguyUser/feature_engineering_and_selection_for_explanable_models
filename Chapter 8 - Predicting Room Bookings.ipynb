# %%
from lightgbm import LGBMRegressor,LGBMClassifier
from sklearn.linear_model import LinearRegression,LogisticRegression
from xgboost import XGBRegressor,XGBClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,f1_score,precision_score,recall_score

from sklearnex import patch_sklearn,unpatch_sklearn

from scipy.stats import f_oneway

import gc
import pickle

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from collections import Counter

from Interaction_effect_features import get_data

from MetaHeuristicsFS import FeatureSelection

# from EvolutionaryFS import GeneticAlgorithmFS
# from SimmulatedAnnealingFS import SimulatedAnnealingFS
# from ACO import AntColonyOptimizationFS
# from PSOFinal import ParticleSwarmOptimizationFS

import shap

np.seterr(divide = 'ignore')
pd.options.mode.chained_assignment = None  # default='warn'
import warnings
# suppress warnings
warnings.filterwarnings('ignore')

# %%
def get_metrics(model,data_dict,problem_type,dependent_variable,features,cost_funct):
    '''
    problem_type = 'regression' or classification
    '''
    
    test_tree_cost = {}
    
    external_tree_cost = []
    external_tree_precision = []
    external_tree_recall = []
    
    data_external_test = data_dict['data_external_test']
    data_validation_test = data_dict['data_validation_test']
    
    #for each training data
    for data_fold_index in data_dict['fold_dict'].keys():
        fold_training = data_dict['fold_dict'][data_fold_index]['fold_training']
        fold_test = data_dict['fold_dict'][data_fold_index]['fold_test']
        
        #based on regression/classification
        if problem_type == 'regression':
            cost_function = cost_funct
        else:
            cost_function = f1_score
        
        Y_train = fold_training[dependent_variable]
        Y_test = fold_test[dependent_variable]
        Y_validation = data_validation_test[dependent_variable]
        Y_external = data_external_test[dependent_variable]
        
        model.fit(fold_training[features],Y_train)
                
        Y_test_tree = model.predict(fold_test[features])
        Y_validation_tree = model.predict(data_validation_test[features])
        Y_external_tree = model.predict(data_external_test[features])
        
        place_holder = np.mean([cost_funct(Y_test,Y_test_tree),cost_funct(Y_validation,Y_validation_tree)])
        
        #predict for test and calculate cost function
        test_tree_cost['CV Sample-'+str(data_fold_index)] = place_holder

        #predict for external test and calculate cost function
        external_tree_cost.append(cost_funct(Y_external,Y_external_tree))
        
        if problem_type != 'regression':
            external_tree_precision.append(precision_score(Y_external,Y_external_tree))
            external_tree_recall.append(recall_score(Y_external,Y_external_tree))
            
    #return cost
    if problem_type != 'regression':
        #print('External Test precision: ' + str(round(np.mean(external_tree_precision),2)) + ', recall: ' + str(round(np.mean(external_tree_recall),2)))
        print('External Test recall: ' + str(round(np.mean(external_tree_recall),2)))
    return test_tree_cost,external_tree_cost

# %%
def make_plot(metric,title,test_tree_cost,external_tree_cost):
    sns.set(rc={'figure.figsize':(16,8)})
    sns.set_context('paper', font_scale = 1.3)
    if metric=='RMSE':
        fig, ax = plt.subplots(1, 2)
    else:
        fig, ax = plt.subplots(1, 2, sharey=True)
        
    validation_name = [' External_Test','External_Test ',' External_Test ',' External_Test  ','  External_Test']

    ax[0].bar(list(test_tree_cost.keys()),list(test_tree_cost.values()))
    ax[0].set_title(metric + ' for test data and validation data')

    ax[1].bar(validation_name,external_tree_cost)
    ax[1].set_title(metric + ' for external test data')

    #plt.title('')
    
def get_data_for_FS(data_dict,dependent_variable,features_all):
    
    data_dict_for_SA = {}

#     x_validation = data_dict['data_external_test'][features_all]
#     y_validation = data_dict['data_external_test'][dependent_variable]
    
    x_validation = data_dict['data_validation_test'][features_all]
    y_validation = data_dict['data_validation_test'][dependent_variable]

    #for each training data
    for data_fold_index in data_dict['fold_dict'].keys():
        
        for feature in features_all:
            if feature not in data_dict['fold_dict'][data_fold_index]['fold_training'].columns:
                print(feature,'not present')

        data_dict_for_SA[data_fold_index]={'x_train':data_dict['fold_dict'][data_fold_index]['fold_training'][features_all],
                                           'y_train':data_dict['fold_dict'][data_fold_index]['fold_training'][dependent_variable],
                                           'x_test':data_dict['fold_dict'][data_fold_index]['fold_test'][features_all],
                                           'y_test':data_dict['fold_dict'][data_fold_index]['fold_test'][dependent_variable]}
    
#     for feature in features_all:
#         if '_Encoded' not in feature:
            
    
    return data_dict_for_SA,x_validation,y_validation,features_all

def last_preprocessing(data_dict):
    
    
    columns = ['AdjustedLeadTime_Quartile_countRankEncoded', 'CumulativeNumberOfRooms_Quartile_percentEncoded', 'CumulativeNumberOfRooms_Quartile_countRankEncoded', 'CumulativeNumberOfRooms_Quartile_MeanEncoded', 'CumulativeNumberOfRoomsSubstract_Quartile_percentEncoded', 'CumulativeNumberOfRoomsSubstract_Quartile_countRankEncoded', 'CumulativeNumberOfRoomsSubstract_Quartile_MeanEncoded', 'CumulativeNumberOfRoomsNet_Quartile_countEncoded', 'CumulativeNumberOfRoomsNet_Quartile_MeanEncoded', 'AdjustedLeadTimeCumulativeNumberOfRooms_Quartile_countEncoded', 'AdjustedLeadTimeCumulativeNumberOfRooms_Quartile_percentEncoded', 'AdjustedLeadTimeCumulativeNumberOfRooms_Quartile_countRankEncoded', 'AdjustedLeadTimeCumulativeNumberOfRooms_Quartile_MeanEncoded', 'AdjustedLeadTimeCumulativeNumberOfRoomsSubstract_Quartile_countRankEncoded', 'AdjustedLeadTimeCumulativeNumberOfRoomsSubstract_Quartile_MeanEncoded', 'AdjustedLeadTimeCumulativeNumberOfRoomsNet_Quartile_percentEncoded', 'CumulativeRevenue_Quartile_countEncoded', 'CumulativeRevenue_Quartile_percentEncoded', 'CumulativeRevenue_Quartile_countRankEncoded', 'CumulativeRevenue_Quartile_MeanEncoded', 'CumulativeRevenueSubstract_Quartile_percentEncoded', 'CumulativeRevenueSubstract_Quartile_countRankEncoded', 'CumulativeRevenueNet_Quartile_percentEncoded', 'CumulativeRevenueNet_Quartile_MeanEncoded', 'AdjustedLeadTimeCumulativeRevenue_Quartile_percentEncoded', 'AdjustedLeadTimeCumulativeRevenue_Quartile_countRankEncoded', 'AdjustedLeadTimeCumulativeRevenueSubstract_Quartile_countEncoded', 'AdjustedLeadTimeCumulativeRevenueSubstract_Quartile_countRankEncoded', 'AdjustedLeadTimeCumulativeRevenueSubstract_Quartile_MeanEncoded', 'AdjustedLeadTimeCumulativeRevenueNet_Quartile_countRankEncoded', 'AdjustedLeadTimeCumulativeRevenueNet_Quartile_MeanEncoded','AdjustedLeadTime_Quartile_percentEncoded', 'CumulativeNumberOfRoomsSubstract_Quartile_countEncoded', 'CumulativeNumberOfRoomsNet_Quartile_percentEncoded', 'AdjustedLeadTimeCumulativeNumberOfRoomsSubstract_Quartile_countEncoded', 'AdjustedLeadTimeCumulativeNumberOfRoomsNet_Quartile_countEncoded', 'AdjustedLeadTimeCumulativeNumberOfRoomsNet_Quartile_countRankEncoded', 'AdjustedLeadTimeCumulativeNumberOfRoomsNet_Quartile_MeanEncoded', 'AdjustedLeadTimeCumulativeRevenue_Quartile_MeanEncoded', 'AdjustedLeadTimeCumulativeRevenueSubstract_Quartile_percentEncoded','AdjustedLeadTime_Quartile_countEncoded', 'CumulativeNumberOfRoomsNet_Quartile_countRankEncoded', 'AdjustedLeadTimeCumulativeNumberOfRoomsSubstract_Quartile_percentEncoded', 'CumulativeRevenueSubstract_Quartile_countEncoded', 'CumulativeRevenueSubstract_Quartile_MeanEncoded', 'CumulativeRevenueNet_Quartile_countEncoded', 'AdjustedLeadTimeCumulativeRevenueNet_Quartile_countEncoded','AdjustedLeadTime_Quartile_MeanEncoded', 'CumulativeNumberOfRooms_Quartile_countEncoded', 'CumulativeRevenueNet_Quartile_countRankEncoded','AdjustedLeadTimeCumulativeRevenue_Quartile_countEncoded', 'AdjustedLeadTimeCumulativeRevenueNet_Quartile_percentEncoded']
    
    for feature in columns:
        if feature in data_dict['data_external_test'].columns:
            data_dict['data_external_test'][feature] = data_dict['data_external_test'][feature].astype(int)
            data_dict['data_validation_test'][feature] = data_dict['data_validation_test'][feature].astype(int)

            for index in data_dict['fold_dict'].keys():
                data_dict['fold_dict'][index]['fold_training'][feature] = data_dict['fold_dict'][index]['fold_training'][feature].astype(int)
                data_dict['fold_dict'][index]['fold_test'][feature] = data_dict['fold_dict'][index]['fold_test'][feature].astype(int)
        
    return data_dict


def cost_funct(y_true,y_pred):
    return np.sqrt(mean_squared_error(y_true,y_pred))

# %%
def filter_features_corr(cutoff,features_all,data_dict_for_linear):

    keep_cols = {}
    common_list = []

    for index in data_dict_for_linear.keys():

        #calculate correlation of all features with dependent variables
        fold_df = data_dict_for_linear[index]['x_train'][features_all]
        fold_df['y_train'] = data_dict_for_linear[index]['y_train']
        fold_corr = fold_df.corr()

        #filter all features below the cutoff and save correlation acceptable features
        keep_cols[index] = list(fold_corr[((fold_corr['y_train'] >=cutoff) | (fold_corr['y_train'] <=-cutoff)) & (fold_corr['y_train'] !=1)].index)

    #find common set of features in all crossvalidation as features to be used
    common_list = set(keep_cols[0]).intersection(set(keep_cols[1])).intersection(set(keep_cols[2])).intersection(set(keep_cols[3])).intersection(set(keep_cols[4]))
    
    return list(common_list)


def filter_features_reg(cutoff,features_all,data_dict_for_linear):

    keep_cols = {}
    common_list = []
    model = LinearRegression(n_jobs=-1)

    for index in data_dict_for_linear.keys():

        #calculate correlation of all features with dependent variables
        X = data_dict_for_linear[index]['x_train'][features_all]
        Y = data_dict_for_linear[index]['y_train']

        #fit linear model
        model.fit(X,Y)

        #get beta of each feature, and create df of feature and beta
        coefficients = pd.DataFrame({"Feature":X.columns,"Coefficients":np.abs(np.transpose(model.coef_).ravel())})

        #cumsum of beta
        coefficients.sort_values(by='Coefficients',inplace=True,ascending=False)
        coefficients.reset_index(inplace=True,drop=True)

        coefficients['cum_sum'] = coefficients['Coefficients'].cumsum()
        coefficients['cum_perc'] = 100*coefficients['cum_sum']/coefficients['Coefficients'].sum()

        #filter at cutoff cumsum, use for feature selection
        keep_cols[index] = list(coefficients[coefficients['cum_perc']<=cutoff].Feature.values)

    #find common set of features in all crossvalidation as features to be used
    common_list = set(keep_cols[0]).intersection(set(keep_cols[1])).intersection(set(keep_cols[2])).intersection(set(keep_cols[3])).intersection(set(keep_cols[4]))


def anova_fs(linear_features_all,data_dict,dependent_variable):
    
    common_list = []
    
    for feature in linear_features_all:
        
        p_counter = 0
        
        for index in data_dict['fold_dict'].keys():
            
            indx_df = data_dict['fold_dict'][index]['fold_training']
            
            class1 = indx_df[indx_df[dependent_variable[0]]==1][feature]
            class2 = indx_df[indx_df[dependent_variable[0]]==0][feature]
            
            stat,p = f_oneway(class1, class2)
            
            if p <= 0.05:
                p_counter += 1
        
        if p_counter == 5:
            common_list.append(feature)
        
    return common_list

# %% [markdown]
# ## Predict Room Booking

# %%
#'HotelCancellations', 'CouponRecommendation', 'PredictRoomBooking','CarSales'
problem = 'PredictRoomBooking'
data_dict,dependent_variable,categorical_linear,categorical_tree,categorical_features,numerical_features_linear,numerical_features_tree,ordinal_features,ordinal_features_engineered = get_data(problem)

data_dict = last_preprocessing(data_dict)
# data_dict_linear = last_preprocessing_linear(data_dict)

linear_features_all = categorical_linear+numerical_features_linear+ordinal_features_engineered
tree_features_all = categorical_tree+numerical_features_tree+ordinal_features_engineered

#data_dict_for_linear,x_validation_linear,y_validation_linear = get_data_for_SA(data_dict,dependent_variable,features_all=linear_features_all)

data_dict_for_tree,x_validation_tree,y_validation_tree,features_all = get_data_for_FS(data_dict,dependent_variable,features_all=tree_features_all)

data_dict_for_linear,x_validation_linear,y_validation_linear,features_all_linear = get_data_for_FS(data_dict,dependent_variable,features_all=linear_features_all)

# %%
#filter by correlation coefficient
cutoff_corr = 0.1
common_list = filter_features_corr(cutoff = cutoff_corr,features_all = linear_features_all,data_dict_for_linear = data_dict_for_linear)

#filter by regression weights
# cutoff_reg = 0.95
# common_list_reg = filter_features_reg(cutoff = cutoff_reg,features_all = linear_features_all,data_dict_for_linear = data_dict_for_linear)

# %% [markdown]
# ### LightGBM

# %%
model_use = LGBMRegressor(random_state=1,n_jobs=-1,n_estimators=200)
fsObj = FeatureSelection(columns_list = tree_features_all,
                         data_dict = data_dict_for_tree,
                         x_validation_dataframe = x_validation_tree,
                         y_validation_dataframe = y_validation_tree,
                         model = model_use,
                         cost_function = cost_funct,
                         cost_function_improvement = 'decrease',
                         average = None)

# %%
#### Particle Swarm Optimization
best_columns_PSO_PredictRoomBooking_lightgbm = fsObj.ParticleSwarmOptimization(iterations = 25,                                                                   
                                                                       swarmSize = 75,
                                                                       run_time=1200)

with open(r"D:\\Results\\ResultPickle\\best_columns_PSO_PredictRoomBooking_lightgbm.pickle", "wb") as output_file:
    pickle.dump(best_columns_PSO_PredictRoomBooking_lightgbm, output_file)
# Out:
# Best combined performance on test and validation data for iteration 0: 18.56686927892919
# Best combined performance on test and validation data for iteration 1: 16.516465920009534
# Best combined performance on test and validation data for iteration 2: 16.51461376306024
# Best combined performance on test and validation data for iteration 3: 16.43981040058953
# Best combined performance on test and validation data for iteration 4: 16.298331720284587
# Best combined performance on test and validation data for iteration 5: 16.29134887305198
# Best combined performance on test and validation data for iteration 6: 16.29134887305198
# Best combined performance on test and validation data for iteration 7: 16.29134887305198
# Best combined performance on test and validation data for iteration 8: 16.29134887305198
# Best combined performance on test and validation data for iteration 9: 16.29134887305198
# Best combined performance on test and validation data for iteration 10: 16.29134887305198
# Best combined performance on test and validation data for iteration 11: 16.29134887305198
# Best combined performance on test and validation data for iteration 12: 16.29134887305198
# Best combined performance on test and validation data for iteration 13: 16.29134887305198
# Best combined performance on test and validation data for iteration 14: 16.28910442365577
# Best combined performance on test and validation data for iteration 15: 16.28910442365577
# Best combined performance on test and validation data for iteration 16: 16.28910442365577
# Best combined performance on test and validation data for iteration 17: 16.28910442365577
# Best combined performance on test and validation data for iteration 18: 16.28910442365577
# Best combined performance on test and validation data for iteration 19: 16.28910442365577
# Best combined performance on test and validation data for iteration 20: 16.28910442365577
# Best combined performance on test and validation data for iteration 21: 16.28910442365577
# Best combined performance on test and validation data for iteration 22: 16.28910442365577
# Best combined performance on test and validation data for iteration 23: 16.28910442365577
# Best combined performance on test and validation data for iteration 24: 16.28910442365577
# ================= Best result: 16.28910442365577 =================
# ================= Execution time in minutes: 264.0 =================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [9], line 7
#       2 best_columns_PSO_PredictRoomBooking_lightgbm = fsObj.ParticleSwarmOptimization(iterations = 25,
#       3                                                                        swarmSize = 75,
#       4                                                                        run_time=1200)
#       6 with open(r"D:\\Results\\ResultPickle\\best_columns_PSO_PredictRoomBooking_lightgbm.pickle", "wb") as output_file:
# ----> 7     pickle.dump(best_columns_PSO_PredictRoomBookings_lightgbm, output_file)
#
# NameError: name 'best_columns_PSO_PredictRoomBookings_lightgbm' is not defined

# %%
#### Ant Colony Optimization
best_columns_ACO_PredictRoomBooking_lightgbm = fsObj.AntColonyOptimization(iterations = 25,
                                                                N_ants = 75,
                                                                run_time=1200,
                                                                evaporation_rate=0.8,
                                                                Q=0.2)

with open(r"D:\\Results\\ResultPickle\\best_columns_ACO_PredictRoomBooking_lightgbm.pickle", "wb") as output_file:
    pickle.dump(best_columns_ACO_PredictRoomBooking_lightgbm, output_file)
# Out:
# Best combined performance on test and validation data for iteration 0: 16.06987591264096
# Best combined performance on test and validation data for iteration 1: 15.413262366988738
# Best combined performance on test and validation data for iteration 2: 15.06423487096231
# Best combined performance on test and validation data for iteration 3: 14.990016513349488
# Best combined performance on test and validation data for iteration 4: 14.981864989733216
# Best combined performance on test and validation data for iteration 5: 14.978191558616956
# Best combined performance on test and validation data for iteration 6: 14.978191558616956
# Best combined performance on test and validation data for iteration 7: 14.978191558616956
# Best combined performance on test and validation data for iteration 8: 14.978191558616956
# Best combined performance on test and validation data for iteration 9: 14.978191558616956
# Best combined performance on test and validation data for iteration 10: 14.978191558616956
# Best combined performance on test and validation data for iteration 11: 14.978191558616956
# Best combined performance on test and validation data for iteration 12: 14.978191558616956
# Best combined performance on test and validation data for iteration 13: 14.978191558616956
# Best combined performance on test and validation data for iteration 14: 14.978191558616956
# Best combined performance on test and validation data for iteration 15: 14.978191558616956
# Best combined performance on test and validation data for iteration 16: 14.978191558616956
# Best combined performance on test and validation data for iteration 17: 14.978191558616956
# Best combined performance on test and validation data for iteration 18: 14.978191558616956
# Best combined performance on test and validation data for iteration 19: 14.978191558616956
# Best combined performance on test and validation data for iteration 20: 14.978191558616956
# Best combined performance on test and validation data for iteration 21: 14.978191558616956
# Best combined performance on test and validation data for iteration 22: 14.978191558616956
# Best combined performance on test and validation data for iteration 23: 14.978191558616956
# Best combined performance on test and validation data for iteration 24: 14.978191558616956
# ================= Best result: 14.978191558616956 =================
# ================= Execution time in minutes: 245.0 =================

# %%
#### Simulated Annealing
best_columns_SA_PredictRoomBooking_lightgbm = fsObj.SimulatedAnnealing(temperature = 1500,
                                                               iterations = 50,
                                                               n_perturb = 75,
                                                               run_time=1200,
                                                               n_features_percent_perturb=1,
                                                               alpha=0.9)

with open(r"D:\\Results\\ResultPickle\\best_columns_SA_PredictRoomBooking_lightgbm.pickle", "wb") as output_file:
    pickle.dump(best_columns_SA_PredictRoomBooking_lightgbm, output_file)
# Out:
# Best combined performance on test and validation data for iteration 0: 19.633861051856037
# Best combined performance on test and validation data for iteration 1: 19.633861051856037
# Best combined performance on test and validation data for iteration 2: 21.66576605456466
# Best combined performance on test and validation data for iteration 3: 21.75050428967806
# Best combined performance on test and validation data for iteration 4: 25.341890921069922
# Best combined performance on test and validation data for iteration 5: 28.263056084667927
# Best combined performance on test and validation data for iteration 6: 18.650942698678218
# Best combined performance on test and validation data for iteration 7: 18.650942698678218
# Best combined performance on test and validation data for iteration 8: 20.60675056297895
# Best combined performance on test and validation data for iteration 9: 20.60675056297895
# Best combined performance on test and validation data for iteration 10: 21.433916759738487
# Best combined performance on test and validation data for iteration 11: 23.17967583458917
# Best combined performance on test and validation data for iteration 12: 25.13824805173031
# Best combined performance on test and validation data for iteration 13: 29.316509982849386
# Best combined performance on test and validation data for iteration 14: 36.973884498731096
# Best combined performance on test and validation data for iteration 15: 40.946111181575176
# Best combined performance on test and validation data for iteration 16: 29.771984243648596
# Best combined performance on test and validation data for iteration 17: 29.771984243648596
# Best combined performance on test and validation data for iteration 18: 32.798711055277344
# Best combined performance on test and validation data for iteration 19: 17.91299097054489
# Best combined performance on test and validation data for iteration 20: 17.91299097054489
# Best combined performance on test and validation data for iteration 21: 20.80088467478408
# Best combined performance on test and validation data for iteration 22: 20.62644431580207
# Best combined performance on test and validation data for iteration 23: 20.62644431580207
# Best combined performance on test and validation data for iteration 24: 20.951813710494513
# Best combined performance on test and validation data for iteration 25: 20.951813710494513
# Best combined performance on test and validation data for iteration 26: 21.293988549814195
# Best combined performance on test and validation data for iteration 27: 23.665183474435462
# Best combined performance on test and validation data for iteration 28: 18.93479699856789
# Best combined performance on test and validation data for iteration 29: 18.93479699856789
# Best combined performance on test and validation data for iteration 30: 19.00543026277898
# Best combined performance on test and validation data for iteration 31: 19.00543026277898
# Best combined performance on test and validation data for iteration 32: 20.28725807620646
# Best combined performance on test and validation data for iteration 33: 20.28725807620646
# Best combined performance on test and validation data for iteration 34: 21.38586749339037
# Best combined performance on test and validation data for iteration 35: 24.224984148075855
# Best combined performance on test and validation data for iteration 36: 28.84426388477999
# Best combined performance on test and validation data for iteration 37: 30.787254512408964
# Best combined performance on test and validation data for iteration 38: 30.787254512408964
# Best combined performance on test and validation data for iteration 39: 22.097694834863766
# Best combined performance on test and validation data for iteration 40: 22.097694834863766
# Best combined performance on test and validation data for iteration 41: 24.783407504957687
# Best combined performance on test and validation data for iteration 42: 24.53645611592101
# Best combined performance on test and validation data for iteration 43: 24.53645611592101
# Best combined performance on test and validation data for iteration 44: 25.087973039113912
# Best combined performance on test and validation data for iteration 45: 24.18259260400164
# Best combined performance on test and validation data for iteration 46: 19.31933769924538
# Best combined performance on test and validation data for iteration 47: 19.31933769924538
# Best combined performance on test and validation data for iteration 48: 19.737816384622924
# Best combined performance on test and validation data for iteration 49: 19.737816384622924
# ================= Best result: 17.91299097054489 =================
# ================= Execution time in minutes: 307.0 =================

# %%
#### Genetic Algorithm
best_columns_GA_PredictRoomBooking_lightgbm = fsObj.GeneticAlgorithm(generations=20,
                                                             population=75,
                                                             run_time=1200)

with open(r"D:\\Results\\ResultPickle\\best_columns_GA_PredictRoomBooking_lightgbm.pickle", "wb") as output_file:
    pickle.dump(best_columns_GA_PredictRoomBooking_lightgbm, output_file)
# Out:
# Best combined performance on test and validation data for generation 0 : 17.4933658572529
# Best combined performance on test and validation data for generation 1 : 15.79591558694597
# Best combined performance on test and validation data for generation 2 : 15.266274645609474
# Best combined performance on test and validation data for generation 3 : 14.000314510582353
# Best combined performance on test and validation data for generation 4 : 14.242632343215869
# Best combined performance on test and validation data for generation 5 : 14.456724675685416
# Best combined performance on test and validation data for generation 6 : 14.263278887770706
# Best combined performance on test and validation data for generation 7 : 14.343453197524951
# Best combined performance on test and validation data for generation 8 : 11.707511389719157
# Best combined performance on test and validation data for generation 9 : 13.812486911465701
# Best combined performance on test and validation data for generation 10 : 11.173627091567434
# Best combined performance on test and validation data for generation 11 : 11.404484834624723
# Best combined performance on test and validation data for generation 12 : 11.927629665917602
# Best combined performance on test and validation data for generation 13 : 13.385674092307926
# Best combined performance on test and validation data for generation 14 : 12.234432634996429
# Best combined performance on test and validation data for generation 15 : 12.342353141038926
# Best combined performance on test and validation data for generation 16 : 12.591703706184113
# Best combined performance on test and validation data for generation 17 : 12.675208203267823
# Best combined performance on test and validation data for generation 18 : 11.446639936165724
# Best combined performance on test and validation data for generation 19 : 13.25477066531634
# ================= Best result: 11.173627091567434 =================
# ================= Execution time in minutes: 496.0 =================

# %%
#model_use = XGBClassifier(n_estimators=500,random_state=1,n_jobs=-1,tree_method = 'gpu_hist')
test_tree_cost,external_tree_cost = get_metrics(model=model_use,
                                                  data_dict=data_dict,
                                                  problem_type = 'regression',
                                                  dependent_variable=dependent_variable,
                                                  features=best_columns_PSO_PredictRoomBooking_lightgbm,
                                                  cost_funct=cost_funct)
print('Average Test and Validation Cost:',round(np.mean(list(test_tree_cost.values())),2),'Average External Test Cost:',round(np.mean(external_tree_cost),2))
metric = 'RMSE'
title = 'Predict Room Booking dataset - Particle Swarm Optimization'
print(title)
make_plot(metric=metric,
          title=title,
          test_tree_cost=test_tree_cost,
          external_tree_cost=external_tree_cost)
# Out:
# Average Test and Validation Cost: 16.29 Average External Test Cost: 13.06
# Predict Room Booking dataset - Particle Swarm Optimization

# %%
#model_use = XGBClassifier(n_estimators=500,random_state=1,n_jobs=-1)#,tree_method = 'gpu_hist')
test_tree_cost,external_tree_cost = get_metrics(model=model_use,
                                                  data_dict=data_dict,
                                                  problem_type = 'regression',
                                                  dependent_variable=dependent_variable,
                                                  features=best_columns_ACO_PredictRoomBooking_lightgbm,
                                                  cost_funct=cost_funct)

print('Average Test and Validation Cost:',round(np.mean(list(test_tree_cost.values())),2),'Average External Test Cost:',round(np.mean(external_tree_cost),2))
metric = 'RMSE'
title = 'Predict Room Booking dataset - Ant Colony Optimization'
print(title)
make_plot(metric=metric,
          title=title,
          test_tree_cost=test_tree_cost,
          external_tree_cost=external_tree_cost)
# Out:
# Average Test and Validation Cost: 14.98 Average External Test Cost: 13.7
# Predict Room Booking dataset - Ant Colony Optimization

# %%
#model_use = XGBClassifier(n_estimators=200,random_state=1,n_jobs=-1)
test_tree_cost,external_tree_cost = get_metrics(model=model_use,
                                                  data_dict=data_dict,
                                                  problem_type = 'regression',
                                                  dependent_variable=dependent_variable,
                                                  features=best_columns_SA_PredictRoomBooking_lightgbm,
                                                  cost_funct=cost_funct)

print('Average Test and Validation Cost:',round(np.mean(list(test_tree_cost.values())),2),'Average External Test Cost:',round(np.mean(external_tree_cost),2))
metric = 'RMSE'
title = 'Predict Room Booking dataset - Simulated Annealing'
print(title)
make_plot(metric=metric,
          title=title,
          test_tree_cost=test_tree_cost,
          external_tree_cost=external_tree_cost)
# Out:
# Average Test and Validation Cost: 17.91 Average External Test Cost: 12.7
# Predict Room Booking dataset - Simulated Annealing

# %%
#model_use = XGBClassifier(n_estimators=500,random_state=1,n_jobs=-1,tree_method = 'gpu_hist')
test_tree_cost,external_tree_cost = get_metrics(model=model_use,
                                                  data_dict=data_dict,
                                                  problem_type = 'regression',
                                                  dependent_variable=dependent_variable,
                                                  features=best_columns_GA_PredictRoomBooking_lightgbm,
                                                  cost_funct=cost_funct)

print('Average Test and Validation Cost:',round(np.mean(list(test_tree_cost.values())),2),'Average External Test Cost:',round(np.mean(external_tree_cost),2))
metric = 'RMSE'
title = 'Predict Room Booking dataset - Genetic Algorithm'
print(title)
make_plot(metric=metric,
          title=title,
          test_tree_cost=test_tree_cost,
          external_tree_cost=external_tree_cost)
# Out:
# Average Test and Validation Cost: 11.17 Average External Test Cost: 11.19
# Predict Room Booking dataset - Genetic Algorithm

# %% [markdown]
# ## Xgboost

# %%
# model_use = LGBMRegressor(random_state=1,n_jobs=-1,n_estimators=100)
model_use = XGBRegressor(n_estimators=200,random_state=1,n_jobs=-1,tree_method = 'gpu_hist')
# model_use = RandomForestRegressor(random_state=1,n_jobs=-1,n_estimators=200)

fsObj = FeatureSelection(columns_list = tree_features_all,
                         data_dict = data_dict_for_tree,
                         x_validation_dataframe = x_validation_tree,
                         y_validation_dataframe = y_validation_tree,
                         model = model_use,
                         cost_function = cost_funct,
                         cost_function_improvement = 'decrease',
                         average = None)

# %%
#### Particle Swarm Optimization
best_columns_PSO_PredictRoomBooking_xgboost = fsObj.ParticleSwarmOptimization(iterations = 25,                                                                   
                                                                       swarmSize = 75,
                                                                       run_time=1200)

with open(r"D:\\Results\\ResultPickle\\best_columns_PSO_PredictRoomBooking_xgboost.pickle", "wb") as output_file:
    pickle.dump(best_columns_PSO_PredictRoomBooking_xgboost, output_file)
# Out:
# Best combined performance on test and validation data for iteration 0: 15.566732273104183
# Best combined performance on test and validation data for iteration 1: 14.833210920102061
# Best combined performance on test and validation data for iteration 2: 14.396002107538658
# Best combined performance on test and validation data for iteration 3: 14.27478872315383
# Best combined performance on test and validation data for iteration 4: 13.388374944397901
# Best combined performance on test and validation data for iteration 5: 13.18649366516028
# Best combined performance on test and validation data for iteration 6: 12.839133486146716
# Best combined performance on test and validation data for iteration 7: 12.839098171767438
# Best combined performance on test and validation data for iteration 8: 12.839098171767438
# Best combined performance on test and validation data for iteration 9: 12.839098171767438
# Best combined performance on test and validation data for iteration 10: 12.839098171767438
# Best combined performance on test and validation data for iteration 11: 12.839098171767438
# Best combined performance on test and validation data for iteration 12: 12.839098171767438
# Best combined performance on test and validation data for iteration 13: 12.831290599571279
# Best combined performance on test and validation data for iteration 14: 12.831290599571279
# Best combined performance on test and validation data for iteration 15: 12.831290599571279
# Best combined performance on test and validation data for iteration 16: 12.803132051529772
# Best combined performance on test and validation data for iteration 17: 12.803132051529772
# Best combined performance on test and validation data for iteration 18: 12.803132051529772
# Best combined performance on test and validation data for iteration 19: 12.803132051529772
# Best combined performance on test and validation data for iteration 20: 12.803132051529772
# Best combined performance on test and validation data for iteration 21: 12.803132051529772
# Best combined performance on test and validation data for iteration 22: 12.803132051529772
# Best combined performance on test and validation data for iteration 23: 12.803132051529772
# Best combined performance on test and validation data for iteration 24: 12.803132051529772
# ================= Best result: 12.803132051529772 =================
# ================= Execution time in minutes: 280.0 =================

# %%
#### Ant Colony Optimization
best_columns_ACO_PredictRoomBooking_xgboost = fsObj.AntColonyOptimization(iterations = 25,
                                                                N_ants = 75,
                                                                run_time=1200,
                                                                evaporation_rate=0.8,
                                                                Q=0.2)

with open(r"D:\\Results\\ResultPickle\\best_columns_ACO_PredictRoomBooking_xgboost.pickle", "wb") as output_file:
    pickle.dump(best_columns_ACO_PredictRoomBooking_xgboost, output_file)
# Out:
# Best combined performance on test and validation data for iteration 0: 14.970980171437194
# Best combined performance on test and validation data for iteration 1: 13.50770671394742
# Best combined performance on test and validation data for iteration 2: 12.5940434304615
# Best combined performance on test and validation data for iteration 3: 11.983068572978983
# Best combined performance on test and validation data for iteration 4: 11.970514839997673
# Best combined performance on test and validation data for iteration 5: 11.970514839997673
# Best combined performance on test and validation data for iteration 6: 11.970514839997673
# Best combined performance on test and validation data for iteration 7: 11.970514839997673
# Best combined performance on test and validation data for iteration 8: 11.970514839997673
# Best combined performance on test and validation data for iteration 9: 11.970514839997673
# Best combined performance on test and validation data for iteration 10: 11.970514839997673
# Best combined performance on test and validation data for iteration 11: 11.970514839997673
# Best combined performance on test and validation data for iteration 12: 11.970514839997673
# Best combined performance on test and validation data for iteration 13: 11.970514839997673
# Best combined performance on test and validation data for iteration 14: 11.970514839997673
# Best combined performance on test and validation data for iteration 15: 11.970514839997673
# Best combined performance on test and validation data for iteration 16: 11.970514839997673
# Best combined performance on test and validation data for iteration 17: 11.970514839997673
# Best combined performance on test and validation data for iteration 18: 11.970514839997673
# Best combined performance on test and validation data for iteration 19: 11.970514839997673
# Best combined performance on test and validation data for iteration 20: 11.970514839997673
# Best combined performance on test and validation data for iteration 21: 11.970514839997673
# Best combined performance on test and validation data for iteration 22: 11.970514839997673
# Best combined performance on test and validation data for iteration 23: 11.970514839997673
# Best combined performance on test and validation data for iteration 24: 11.970514839997673
# ================= Best result: 11.970514839997673 =================
# ================= Execution time in minutes: 286.0 =================

# %%
#### Simulated Annealing
best_columns_SA_PredictRoomBooking_xgboost = fsObj.SimulatedAnnealing(temperature = 1500,
                                                               iterations = 50,
                                                               n_perturb = 75,
                                                               run_time=1200,
                                                               n_features_percent_perturb=1,
                                                               alpha=0.9)

with open(r"D:\\Results\\ResultPickle\\best_columns_SA_PredictRoomBooking_xgboost.pickle", "wb") as output_file:
    pickle.dump(best_columns_SA_PredictRoomBooking_xgboost, output_file)
# Out:
# Best combined performance on test and validation data for iteration 0: 31.883395531474434
# Best combined performance on test and validation data for iteration 1: 31.883395531474434
# Best combined performance on test and validation data for iteration 2: 31.180984401644043
# Best combined performance on test and validation data for iteration 3: 27.626714611808257
# Best combined performance on test and validation data for iteration 4: 27.626714611808257
# Best combined performance on test and validation data for iteration 5: 24.554031329297676
# Best combined performance on test and validation data for iteration 6: 24.554031329297676
# Best combined performance on test and validation data for iteration 7: 21.99697640844301
# Best combined performance on test and validation data for iteration 8: 21.99697640844301
# Best combined performance on test and validation data for iteration 9: 24.749103695347863
# Best combined performance on test and validation data for iteration 10: 27.1344718563946
# Best combined performance on test and validation data for iteration 11: 23.329028294597236
# Best combined performance on test and validation data for iteration 12: 22.81170210219246
# Best combined performance on test and validation data for iteration 13: 22.81170210219246
# Best combined performance on test and validation data for iteration 14: 23.05725813559989
# Best combined performance on test and validation data for iteration 15: 30.05545399165344
# Best combined performance on test and validation data for iteration 16: 32.248839071257734
# Best combined performance on test and validation data for iteration 17: 33.98468213969806
# Best combined performance on test and validation data for iteration 18: 27.402906401657624
# Best combined performance on test and validation data for iteration 19: 23.523316779120904
# Best combined performance on test and validation data for iteration 20: 23.522823298896792
# Best combined performance on test and validation data for iteration 21: 23.522823298896792
# Best combined performance on test and validation data for iteration 22: 26.63895256424636
# Best combined performance on test and validation data for iteration 23: 20.39902036129601
# Best combined performance on test and validation data for iteration 24: 20.39902036129601
# Best combined performance on test and validation data for iteration 25: 24.985181875858196
# Best combined performance on test and validation data for iteration 26: 31.243788469435913
# Best combined performance on test and validation data for iteration 27: 26.70127656544262
# Best combined performance on test and validation data for iteration 28: 26.70127656544262
# Best combined performance on test and validation data for iteration 29: 32.99628695912348
# Best combined performance on test and validation data for iteration 30: 32.07268323957887
# Best combined performance on test and validation data for iteration 31: 30.14713900287897
# Best combined performance on test and validation data for iteration 32: 26.21913387507335
# Best combined performance on test and validation data for iteration 33: 26.21913387507335
# Best combined performance on test and validation data for iteration 34: 27.379399658083788
# Best combined performance on test and validation data for iteration 35: 27.379399658083788
# Best combined performance on test and validation data for iteration 36: 24.41253276061541
# Best combined performance on test and validation data for iteration 37: 21.951790611579273
# Best combined performance on test and validation data for iteration 38: 19.109371454682027
# Best combined performance on test and validation data for iteration 39: 19.109371454682027
# Best combined performance on test and validation data for iteration 40: 19.916518734926335
# Best combined performance on test and validation data for iteration 41: 20.4228450442667
# Best combined performance on test and validation data for iteration 42: 20.4228450442667
# Best combined performance on test and validation data for iteration 43: 25.049566091644465
# Best combined performance on test and validation data for iteration 44: 26.028507214498624
# Best combined performance on test and validation data for iteration 45: 28.028975898854462
# Best combined performance on test and validation data for iteration 46: 23.991433989834043
# Best combined performance on test and validation data for iteration 47: 23.991433989834043
# Best combined performance on test and validation data for iteration 48: 27.452847821880248
# Best combined performance on test and validation data for iteration 49: 31.63439669819981
# ================= Best result: 19.109371454682027 =================
# ================= Execution time in minutes: 459.0 =================

# %%
#### Genetic Algorithm
best_columns_GA_PredictRoomBooking_xgboost = fsObj.GeneticAlgorithm(generations=20,
                                                             population=75,
                                                             run_time=1200)

with open(r"D:\\Results\\ResultPickle\\best_columns_GA_PredictRoomBooking_xgboost.pickle", "wb") as output_file:
    pickle.dump(best_columns_GA_PredictRoomBooking_xgboost, output_file)
# Out:
# Best combined performance on test and validation data for generation 0 : 10.846244536185685
# Best combined performance on test and validation data for generation 1 : 14.720267482405589
# Best combined performance on test and validation data for generation 2 : 13.54480566120316
# Best combined performance on test and validation data for generation 3 : 13.810323494761793
# Best combined performance on test and validation data for generation 4 : 12.490870992376736
# Best combined performance on test and validation data for generation 5 : 12.04747024075549
# Best combined performance on test and validation data for generation 6 : 11.36160888457563
# Best combined performance on test and validation data for generation 7 : 12.595967290116311
# Best combined performance on test and validation data for generation 8 : 13.665149141705879
# Best combined performance on test and validation data for generation 9 : 12.70160515881298
# Best combined performance on test and validation data for generation 10 : 12.670447939399494
# Best combined performance on test and validation data for generation 11 : 13.3945807134705
# Best combined performance on test and validation data for generation 12 : 11.941070748328453
# Best combined performance on test and validation data for generation 13 : 11.99962205940307
# Best combined performance on test and validation data for generation 14 : 12.005492776201141
# Best combined performance on test and validation data for generation 15 : 11.430298712119143
# Best combined performance on test and validation data for generation 16 : 12.045092134293018
# Best combined performance on test and validation data for generation 17 : 12.790546033971625
# Best combined performance on test and validation data for generation 18 : 12.670680301716951
# Best combined performance on test and validation data for generation 19 : 11.976418472388033
# ================= Best result: 10.846244536185685 =================
# ================= Execution time in minutes: 764.0 =================

# %%
#model_use = XGBClassifier(n_estimators=500,random_state=1,n_jobs=-1,tree_method = 'gpu_hist')
test_tree_cost,external_tree_cost = get_metrics(model=model_use,
                                                  data_dict=data_dict,
                                                  problem_type = 'regression',
                                                  dependent_variable=dependent_variable,
                                                  features=best_columns_PSO_PredictRoomBooking_xgboost,
                                                  cost_funct=cost_funct)
print('Average Test and Validation Cost:',round(np.mean(list(test_tree_cost.values())),2),'Average External Test Cost:',round(np.mean(external_tree_cost),2))
metric = 'RMSE'
title = 'Predict Room Booking dataset - Particle Swarm Optimization'
print(title)
make_plot(metric=metric,
          title=title,
          test_tree_cost=test_tree_cost,
          external_tree_cost=external_tree_cost)
# Out:
# Average Test and Validation Cost: 12.8 Average External Test Cost: 11.77
# Predict Room Booking dataset - Particle Swarm Optimization

# %%
#model_use = XGBClassifier(n_estimators=500,random_state=1,n_jobs=-1)#,tree_method = 'gpu_hist')
test_tree_cost,external_tree_cost = get_metrics(model=model_use,
                                                  data_dict=data_dict,
                                                  problem_type = 'regression',
                                                  dependent_variable=dependent_variable,
                                                  features=best_columns_ACO_PredictRoomBooking_xgboost,
                                                  cost_funct=cost_funct)

print('Average Test and Validation Cost:',round(np.mean(list(test_tree_cost.values())),2),'Average External Test Cost:',round(np.mean(external_tree_cost),2))
metric = 'RMSE'
title = 'Predict Room Booking dataset - Ant Colony Optimization'
print(title)
make_plot(metric=metric,
          title=title,
          test_tree_cost=test_tree_cost,
          external_tree_cost=external_tree_cost)
# Out:
# Average Test and Validation Cost: 11.97 Average External Test Cost: 12.33
# Predict Room Booking dataset - Ant Colony Optimization

# %%
#model_use = XGBClassifier(n_estimators=200,random_state=1,n_jobs=-1)
test_tree_cost,external_tree_cost = get_metrics(model=model_use,
                                                  data_dict=data_dict,
                                                  problem_type = 'regression',
                                                  dependent_variable=dependent_variable,
                                                  features=best_columns_SA_PredictRoomBooking_xgboost,
                                                  cost_funct=cost_funct)

print('Average Test and Validation Cost:',round(np.mean(list(test_tree_cost.values())),2),'Average External Test Cost:',round(np.mean(external_tree_cost),2))
metric = 'RMSE'
title = 'Predict Room Booking dataset - Simulated Annealing'
print(title)
make_plot(metric=metric,
          title=title,
          test_tree_cost=test_tree_cost,
          external_tree_cost=external_tree_cost)
# Out:
# Average Test and Validation Cost: 19.11 Average External Test Cost: 19.96
# Predict Room Booking dataset - Simulated Annealing

# %%
#model_use = XGBClassifier(n_estimators=500,random_state=1,n_jobs=-1,tree_method = 'gpu_hist')
test_tree_cost,external_tree_cost = get_metrics(model=model_use,
                                                  data_dict=data_dict,
                                                  problem_type = 'regression',
                                                  dependent_variable=dependent_variable,
                                                  features=best_columns_GA_PredictRoomBooking_xgboost,
                                                  cost_funct=cost_funct)

print('Average Test and Validation Cost:',round(np.mean(list(test_tree_cost.values())),2),'Average External Test Cost:',round(np.mean(external_tree_cost),2))
metric = 'RMSE'
title = 'Predict Room Booking dataset - Genetic Algorithm'
print(title)
make_plot(metric=metric,
          title=title,
          test_tree_cost=test_tree_cost,
          external_tree_cost=external_tree_cost)
# Out:
# Average Test and Validation Cost: 10.85 Average External Test Cost: 11.49
# Predict Room Booking dataset - Genetic Algorithm

# %% [markdown]
# ## Linear Regression

# %%
patch_sklearn()
model_use = LinearRegression(n_jobs=-1)

#common_list
#linear_features_all

fsObj = FeatureSelection(columns_list = linear_features_all,
                         data_dict = data_dict_for_linear,
                         x_validation_dataframe = x_validation_linear,
                         y_validation_dataframe = y_validation_linear,
                         model = model_use,
                         cost_function = cost_funct,
                         cost_function_improvement = 'decrease',
                         average = None)
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
#### Particle Swarm Optimization
best_columns_PSO_PredictRoomBooking_linear = fsObj.ParticleSwarmOptimization(iterations = 25,                                                                   
                                                                       swarmSize = 100,
                                                                       run_time=1200)

with open(r"D:\\Results\\ResultPickle\\best_columns_PSO_PredictRoomBooking_linear.pickle", "wb") as output_file:
    pickle.dump(best_columns_PSO_PredictRoomBooking_linear, output_file)
# Out:
# Best combined performance on test and validation data for iteration 0: 36.62963765782809
# Best combined performance on test and validation data for iteration 1: 36.62963765782809
# Best combined performance on test and validation data for iteration 2: 32.573909737391375
# Best combined performance on test and validation data for iteration 3: 29.429721151039917
# Best combined performance on test and validation data for iteration 4: 29.429721151039917
# Best combined performance on test and validation data for iteration 5: 28.364197232373584
# Best combined performance on test and validation data for iteration 6: 28.364197232373584
# Best combined performance on test and validation data for iteration 7: 27.729322439758214
# Best combined performance on test and validation data for iteration 8: 27.729322439758214
# Best combined performance on test and validation data for iteration 9: 27.729322439758214
# Best combined performance on test and validation data for iteration 10: 27.729322439758214
# Best combined performance on test and validation data for iteration 11: 27.729322439758214
# Best combined performance on test and validation data for iteration 12: 27.729322439758214
# Best combined performance on test and validation data for iteration 13: 27.729322439758214
# Best combined performance on test and validation data for iteration 14: 27.42464367065238
# Best combined performance on test and validation data for iteration 15: 26.926565344704365
# Best combined performance on test and validation data for iteration 16: 26.75026683163271
# Best combined performance on test and validation data for iteration 17: 26.64581809820364
# Best combined performance on test and validation data for iteration 18: 26.604576523932217
# Best combined performance on test and validation data for iteration 19: 26.597611378208036
# Best combined performance on test and validation data for iteration 20: 26.56729788478982
# Best combined performance on test and validation data for iteration 21: 26.35512967998627
# Best combined performance on test and validation data for iteration 22: 26.327641834220106
# Best combined performance on test and validation data for iteration 23: 26.326984281045647
# Best combined performance on test and validation data for iteration 24: 26.302532781420194
# ================= Best result: 26.302532781420194 =================
# ================= Execution time in minutes: 73.0 =================

# %%
#### Ant Colony Optimization
best_columns_ACO_PredictRoomBooking_linear = fsObj.AntColonyOptimization(iterations = 25,
                                                                N_ants = 100,
                                                                run_time=1200,
                                                                evaporation_rate=0.8,
                                                                Q=0.2)

with open(r"D:\\Results\\ResultPickle\\best_columns_ACO_PredictRoomBooking_linear.pickle", "wb") as output_file:
    pickle.dump(best_columns_ACO_PredictRoomBooking_linear, output_file)
# Out:
# Best combined performance on test and validation data for iteration 0: 33.9558344474459
# Best combined performance on test and validation data for iteration 1: 33.9558344474459
# Best combined performance on test and validation data for iteration 2: 33.9558344474459
# Best combined performance on test and validation data for iteration 3: 33.9558344474459
# Best combined performance on test and validation data for iteration 4: 32.94672840285293
# Best combined performance on test and validation data for iteration 5: 31.643498938939313
# Best combined performance on test and validation data for iteration 6: 31.643498938939313
# Best combined performance on test and validation data for iteration 7: 30.81396657118514
# Best combined performance on test and validation data for iteration 8: 30.49014648854357
# Best combined performance on test and validation data for iteration 9: 29.78040671707159
# Best combined performance on test and validation data for iteration 10: 29.749658072218494
# Best combined performance on test and validation data for iteration 11: 29.633812403976304
# Best combined performance on test and validation data for iteration 12: 29.56022080858404
# Best combined performance on test and validation data for iteration 13: 29.48390698859048
# Best combined performance on test and validation data for iteration 14: 29.414674273047307
# Best combined performance on test and validation data for iteration 15: 29.34885574290854
# Best combined performance on test and validation data for iteration 16: 29.30870587600591
# Best combined performance on test and validation data for iteration 17: 29.193915848899422
# Best combined performance on test and validation data for iteration 18: 29.191152265708958
# Best combined performance on test and validation data for iteration 19: 29.191146524061793
# Best combined performance on test and validation data for iteration 20: 29.18752942640976
# Best combined performance on test and validation data for iteration 21: 29.187523708945367
# Best combined performance on test and validation data for iteration 22: 29.186676326247458
# Best combined performance on test and validation data for iteration 23: 29.17769737552872
# Best combined performance on test and validation data for iteration 24: 29.17769737552872
# ================= Best result: 29.17769737552872 =================
# ================= Execution time in minutes: 148.0 =================

# %%
#### Simulated Annealing
best_columns_SA_PredictRoomBooking_linear = fsObj.SimulatedAnnealing(temperature = 1500,
                                                               iterations = 35,
                                                               n_perturb = 100,
                                                               run_time=1200,
                                                               n_features_percent_perturb=1,
                                                               alpha=0.9)

with open(r"D:\\Results\\ResultPickle\\best_columns_SA_PredictRoomBooking_linear.pickle", "wb") as output_file:
    pickle.dump(best_columns_SA_PredictRoomBooking_linear, output_file)
# Out:
# Best combined performance on test and validation data for iteration 0: 57.860966640322275
# Best combined performance on test and validation data for iteration 1: 39.91800847975971
# Best combined performance on test and validation data for iteration 2: 39.91800847975971
# Best combined performance on test and validation data for iteration 3: 46.30299990575589
# Best combined performance on test and validation data for iteration 4: 50.540956383264515
# Best combined performance on test and validation data for iteration 5: 44.25132477418461
# Best combined performance on test and validation data for iteration 6: 49.87552368113889
# Best combined performance on test and validation data for iteration 7: 50.503729455604514
# Best combined performance on test and validation data for iteration 8: 43.823573276517905
# Best combined performance on test and validation data for iteration 9: 45.72521746507481
# Best combined performance on test and validation data for iteration 10: 52.60654183124974
# Best combined performance on test and validation data for iteration 11: 52.710052288371344
# Best combined performance on test and validation data for iteration 12: 55.21689955941055
# Best combined performance on test and validation data for iteration 13: 51.96127224778088
# Best combined performance on test and validation data for iteration 14: 41.963074252165995
# Best combined performance on test and validation data for iteration 15: 41.963074252165995
# Best combined performance on test and validation data for iteration 16: 40.67894030444383
# Best combined performance on test and validation data for iteration 17: 38.49723353426767
# Best combined performance on test and validation data for iteration 18: 38.49723353426767
# Best combined performance on test and validation data for iteration 19: 44.42172789969946
# Best combined performance on test and validation data for iteration 20: 45.30135251141694
# Best combined performance on test and validation data for iteration 21: 36.630534324258704
# Best combined performance on test and validation data for iteration 22: 34.44248433067706
# Best combined performance on test and validation data for iteration 23: 34.44248433067706
# Best combined performance on test and validation data for iteration 24: 38.45223326730494
# Best combined performance on test and validation data for iteration 25: 40.41417946362917
# Best combined performance on test and validation data for iteration 26: 40.41417946362917
# Best combined performance on test and validation data for iteration 27: 33.796975241618455
# Best combined performance on test and validation data for iteration 28: 33.796975241618455
# Best combined performance on test and validation data for iteration 29: 38.600513454591656
# Best combined performance on test and validation data for iteration 30: 39.398967627398164
# Best combined performance on test and validation data for iteration 31: 39.398967627398164
# Best combined performance on test and validation data for iteration 32: 41.19320197213749
# Best combined performance on test and validation data for iteration 33: 41.19320197213749
# Best combined performance on test and validation data for iteration 34: 45.49007524999622
# ================= Best result: 33.796975241618455 =================
# ================= Execution time in minutes: 106.0 =================

# %%
#### Genetic Algorithm
best_columns_GA_PredictRoomBooking_linear = fsObj.GeneticAlgorithm(generations=25,
                                                             population=100,
                                                             run_time=1200)

with open(r"D:\\Results\\ResultPickle\\best_columns_GA_PredictRoomBooking_linear.pickle", "wb") as output_file:
    pickle.dump(best_columns_GA_PredictRoomBooking_linear, output_file)
# Out:
# Best combined performance on test and validation data for generation 0 : 39.84634234137498
# Best combined performance on test and validation data for generation 1 : 33.81100163507303
# Best combined performance on test and validation data for generation 2 : 33.74687751445232
# Best combined performance on test and validation data for generation 3 : 34.63227887803078
# Best combined performance on test and validation data for generation 4 : 34.370821264349956
# Best combined performance on test and validation data for generation 5 : 32.99048597236549
# Best combined performance on test and validation data for generation 6 : 31.46087899449766
# Best combined performance on test and validation data for generation 7 : 31.9177827862217
# Best combined performance on test and validation data for generation 8 : 30.95533684373633
# Best combined performance on test and validation data for generation 9 : 32.58520208698992
# Best combined performance on test and validation data for generation 10 : 31.411209291815748
# Best combined performance on test and validation data for generation 11 : 32.983861158773436
# Best combined performance on test and validation data for generation 12 : 31.328142153899837
# Best combined performance on test and validation data for generation 13 : 31.8846402540784
# Best combined performance on test and validation data for generation 14 : 30.744066950436412
# Best combined performance on test and validation data for generation 15 : 30.93394519078314
# Best combined performance on test and validation data for generation 16 : 32.558423924723925
# Best combined performance on test and validation data for generation 17 : 34.84040539673828
# Best combined performance on test and validation data for generation 18 : 34.55843000212351
# Best combined performance on test and validation data for generation 19 : 33.7396816919982
# Best combined performance on test and validation data for generation 20 : 32.37572243518042
# Best combined performance on test and validation data for generation 21 : 30.701818054039496
# Best combined performance on test and validation data for generation 22 : 30.30162805806293
# Best combined performance on test and validation data for generation 23 : 33.49420823518939
# Best combined performance on test and validation data for generation 24 : 31.449761158907457
# ================= Best result: 30.30162805806293 =================
# ================= Execution time in minutes: 302.0 =================

# %%
#model_use = XGBClassifier(n_estimators=500,random_state=1,n_jobs=-1,tree_method = 'gpu_hist')
test_tree_cost,external_tree_cost = get_metrics(model=model_use,
                                                  data_dict=data_dict,
                                                  problem_type = 'regression',
                                                  dependent_variable=dependent_variable,
                                                  features=best_columns_PSO_PredictRoomBooking_linear,
                                                  cost_funct=cost_funct)
print('Average Test and Validation Cost:',round(np.mean(list(test_tree_cost.values())),2),'Average External Test Cost:',round(np.mean(external_tree_cost),2))
metric = 'RMSE'
title = 'Predict Room Booking dataset - Particle Swarm Optimization'
print(title)
make_plot(metric=metric,
          title=title,
          test_tree_cost=test_tree_cost,
          external_tree_cost=external_tree_cost)
# Out:
# Average Test and Validation Cost: 26.3 Average External Test Cost: 25.48
# Predict Room Booking dataset - Particle Swarm Optimization

# %%
test_tree_cost,external_tree_cost = get_metrics(model=model_use,
                                                  data_dict=data_dict,
                                                  problem_type = 'regression',
                                                  dependent_variable=dependent_variable,
                                                  features=best_columns_ACO_PredictRoomBooking_linear,
                                                  cost_funct=cost_funct)

print('Average Test and Validation Cost:',round(np.mean(list(test_tree_cost.values())),2),'Average External Test Cost:',round(np.mean(external_tree_cost),2))
metric = 'RMSE'
title = 'Predict Room Booking dataset - Ant Colony Optimization'
print(title)
make_plot(metric=metric,
          title=title,
          test_tree_cost=test_tree_cost,
          external_tree_cost=external_tree_cost)
# Out:
# Average Test and Validation Cost: 29.18 Average External Test Cost: 27.35
# Predict Room Booking dataset - Ant Colony Optimization

# %%
test_tree_cost,external_tree_cost = get_metrics(model=model_use,
                                                  data_dict=data_dict,
                                                  problem_type = 'regression',
                                                  dependent_variable=dependent_variable,
                                                  features=best_columns_SA_PredictRoomBooking_linear,
                                                  cost_funct=cost_funct)

print('Average Test and Validation Cost:',round(np.mean(list(test_tree_cost.values())),2),'Average External Test Cost:',round(np.mean(external_tree_cost),2))
metric = 'RMSE'
title = 'Predict Room Booking dataset - Simulated Annealing'
print(title)
make_plot(metric=metric,
          title=title,
          test_tree_cost=test_tree_cost,
          external_tree_cost=external_tree_cost)
# Out:
# Average Test and Validation Cost: 33.8 Average External Test Cost: 33.29
# Predict Room Booking dataset - Simulated Annealing

# %%
test_tree_cost,external_tree_cost = get_metrics(model=model_use,
                                                  data_dict=data_dict,
                                                  problem_type = 'regression',
                                                  dependent_variable=dependent_variable,
                                                  features=best_columns_GA_PredictRoomBooking_linear,
                                                  cost_funct=cost_funct)

print('Average Test and Validation Cost:',round(np.mean(list(test_tree_cost.values())),2),'Average External Test Cost:',round(np.mean(external_tree_cost),2))
metric = 'RMSE'
title = 'Predict Room Booking dataset - Genetic Algorithm'
print(title)
make_plot(metric=metric,
          title=title,
          test_tree_cost=test_tree_cost,
          external_tree_cost=external_tree_cost)
# Out:
# Average Test and Validation Cost: 30.3 Average External Test Cost: 29.17
# Predict Room Booking dataset - Genetic Algorithm

# %%
unpatch_sklearn()
